# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("loan.csv")

# %%
dataset.head()
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0         NaN           yes
# 2      5.0    male     NaN         2.0  ungraduate           NaN
# 3     65.0     NaN      no         NaN         NaN            no
# 4    767.0  female     yes         2.0    graduate           NaN
#
#    applicantincome  coapplicant_income  loan_amount property
# 0         453453.0                   0          232    urban
# 1           5435.0                3434          232    rural
# 2           4545.0                   3           32    rural
# 3              NaN                3434            2    urban
# 4              NaN                3445          323    rural

# %%
dataset["applicantincome"].fillna(34044823,inplace=True)

# %%
dataset
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0         NaN           yes
# 2      5.0    male     NaN         2.0  ungraduate           NaN
# 3     65.0     NaN      no         NaN         NaN            no
# 4    767.0  female     yes         2.0    graduate           NaN
# 5      8.0     NaN     NaN         NaN         NaN           yes
# 6     78.0  female     NaN         1.0  ungraduate           NaN
# 7      NaN    male     yes         0.0         NaN           yes
# 8     89.0     NaN      no         NaN         NaN            no
#
#    applicantincome  coapplicant_income  loan_amount property
# 0         453453.0                   0          232    urban
# 1           5435.0                3434          232    rural
# 2           4545.0                   3           32    rural
# 3       34044823.0                3434            2    urban
# ...

# %%
dataset.isnull().sum()
# Out:
# loan_id               1
# Gender                3
# Married               3
# Dependents            3
# Education             5
# self_employed         3
# applicantincome       0
# coapplicant_income    0
# loan_amount           0
# property              0
# dtype: int64

# %%
sns.histplot(dataset["applicantincome"] ,kde=True)
plt.show()

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
mm=MinMaxScaler()

# %%
dataset["applicantincome-nn"]=pd.DataFrame(mm.fit_transform(dataset[["applicantincome"]]),columns=["x"])

# %%
dataset
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0         NaN           yes
# 2      5.0    male     NaN         2.0  ungraduate           NaN
# 3     65.0     NaN      no         NaN         NaN            no
# 4    767.0  female     yes         2.0    graduate           NaN
# 5      8.0     NaN     NaN         NaN         NaN           yes
# 6     78.0  female     NaN         1.0  ungraduate           NaN
# 7      NaN    male     yes         0.0         NaN           yes
# 8     89.0     NaN      no         NaN         NaN            no
#
#    applicantincome  coapplicant_income  loan_amount property  \
# 0         453453.0                   0          232    urban
# 1           5435.0                3434          232    rural
# 2           4545.0                   3           32    rural
# 3       34044823.0                3434            2    urban
# ...

# %%
plt.figure(figsize=(14,4))
plt.subplot(1,2,1)
plt.title("Before")
sns.histplot(dataset["applicantincome"] ,kde=True)

plt.subplot(1,2,2)
plt.title("After")
sns.histplot(dataset["applicantincome-nn"] , kde=True)
plt.show()
