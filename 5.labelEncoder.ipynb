# %%
import pandas as pd

# %%
df=pd.DataFrame({"name":["cat","cow","dog"]})

# %%
df
# Out:
#   name
# 0  cat
# 1  cow
# 2  dog

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df["en_name"]=le.fit_transform(df["name"])

# %%
df
# Out:
#   name  en_name
# 0  cat        0
# 1  cow        1
# 2  dog        2

# %%
dataset=pd.read_csv("loan.csv")

# %%
dataset.head(10)
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0         NaN           yes
# 2      5.0    male     NaN         2.0  ungraduate           NaN
# 3     65.0     NaN      no         NaN         NaN            no
# 4    767.0  female     yes         2.0    graduate           NaN
# 5      8.0     NaN     NaN         NaN         NaN           yes
# 6     78.0  female     NaN         1.0  ungraduate           NaN
# 7      NaN    male     yes         0.0         NaN           yes
# 8     89.0     NaN      no         NaN         NaN            no
#
#    applicantincome  coapplicant_income  loan_amount property
# 0         453453.0                   0          232    urban
# 1           5435.0                3434          232    rural
# 2           4545.0                   3           32    rural
# 3              NaN                3434            2    urban
# ...

# %%
la=LabelEncoder()

# %%
dataset["loan_amount"].unique()
# Out:
# array([232,  32,   2, 323])

# %%
la.fit(dataset["loan_amount"])
# Out:
# LabelEncoder()

# %%
dataset["amounttt"]=la.transform(dataset["loan_amount"])

# %%
dataset
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0         NaN           yes
# 2      5.0    male     NaN         2.0  ungraduate           NaN
# 3     65.0     NaN      no         NaN         NaN            no
# 4    767.0  female     yes         2.0    graduate           NaN
# 5      8.0     NaN     NaN         NaN         NaN           yes
# 6     78.0  female     NaN         1.0  ungraduate           NaN
# 7      NaN    male     yes         0.0         NaN           yes
# 8     89.0     NaN      no         NaN         NaN            no
#
#    applicantincome  coapplicant_income  loan_amount property  amounttt
# 0         453453.0                   0          232    urban         2
# 1           5435.0                3434          232    rural         2
# 2           4545.0                   3           32    rural         1
# ...
