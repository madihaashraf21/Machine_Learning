# %%
import pandas as pd

# %%
# df=pd.DataFrame({"Size":["s","m","l","Xl","s","m","Xl","l"]})

# %%
df
# Out:
#   Size
# 0    s
# 1    m
# 2    l
# 3   Xl
# 4    s
# 5    m
# 6   Xl
# 7    l

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
order_size=[["s","m","l","Xl"]]

# %%
ol=OrdinalEncoder(categories=order_size)

# %%
ol.fit(df[["Size"]])
# Out:
# OrdinalEncoder(categories=[['s', 'm', 'l', 'Xl']])

# %%
df["another_size"]=ol.transform(df[["Size"]])

# %%
df
# Out:
#   Size  another_size
# 0    s           0.0
# 1    m           1.0
# 2    l           2.0
# 3   Xl           3.0
# 4    s           0.0
# 5    m           1.0
# 6   Xl           3.0
# 7    l           2.0

# %%
order_data1={"s":0,"m":1,"l":2,"Xl":3}

# %%
df["size_en_map"]=df["Size"].map(order_data1)

# %%
df
# Out:
#   Size  another_size  size_en_map
# 0    s           0.0            0
# 1    m           1.0            1
# 2    l           2.0            2
# 3   Xl           3.0            3
# 4    s           0.0            0
# 5    m           1.0            1
# 6   Xl           3.0            3
# 7    l           2.0            2

# %%
dataset=pd.read_csv("loan.csv")

# %%
dataset.head(10)
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0         NaN           yes
# 2      5.0    male     NaN         2.0  ungraduate           NaN
# 3     65.0     NaN      no         NaN         NaN            no
# 4    767.0  female     yes         2.0    graduate           NaN
# 5      8.0     NaN     NaN         NaN         NaN           yes
# 6     78.0  female     NaN         1.0  ungraduate           NaN
# 7      NaN    male     yes         0.0         NaN           yes
# 8     89.0     NaN      no         NaN         NaN            no
#
#    applicantincome  coapplicant_income  loan_amount property
# 0         453453.0                   0          232    urban
# 1           5435.0                3434          232    rural
# 2           4545.0                   3           32    rural
# 3              NaN                3434            2    urban
# ...

# %%
dataset["loan_amount"].unique()
# Out:
# array([232,  32,   2, 323])

# %%
dataset["self_employed"].unique()
# Out:
# array(['no', 'yes'], dtype=object)

# %%
dataset.fillna({"self_employed":dataset["self_employed"].mode()[0]},inplace=True)

# %%
order_data2=[["yes","no"]]

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
oii=OrdinalEncoder(categories=order_data2)

# %%
dataset["is_Employed"]=oii.fit_transform(dataset[["self_employed"]])

# %%
dataset
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0         NaN           yes
# 2      5.0    male     NaN         2.0  ungraduate            no
# 3     65.0     NaN      no         NaN         NaN            no
# 4    767.0  female     yes         2.0    graduate            no
# 5      8.0     NaN     NaN         NaN         NaN           yes
# 6     78.0  female     NaN         1.0  ungraduate            no
# 7      NaN    male     yes         0.0         NaN           yes
# 8     89.0     NaN      no         NaN         NaN            no
#
#    applicantincome  coapplicant_income  loan_amount property  is_Employed
# 0         453453.0                   0          232    urban          1.0
# 1           5435.0                3434          232    rural          0.0
# 2           4545.0                   3           32    rural          1.0
# ...

# %%
order_size4={"yes":1,"no":5}

# %%
dataset["self_employed_in_map"]=dataset["self_employed"].map(order_size4)

# %%
dataset
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0         NaN           yes
# 2      5.0    male     NaN         2.0  ungraduate            no
# 3     65.0     NaN      no         NaN         NaN            no
# 4    767.0  female     yes         2.0    graduate            no
# 5      8.0     NaN     NaN         NaN         NaN           yes
# 6     78.0  female     NaN         1.0  ungraduate            no
# 7      NaN    male     yes         0.0         NaN           yes
# 8     89.0     NaN      no         NaN         NaN            no
#
#    applicantincome  coapplicant_income  loan_amount property  is_Employed  \
# 0         453453.0                   0          232    urban          1.0
# 1           5435.0                3434          232    rural          0.0
# 2           4545.0                   3           32    rural          1.0
# ...
