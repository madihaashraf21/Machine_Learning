# %%
import pandas as pd

# %%
dataset=pd.read_csv("loan.csv")

# %%
dataset
# Out:
#     loan_id  Gender Married Dependents   Education self_employed  \
# 0      12.0    male      no          0    graduate            no
# 1      34.0  female     yes          1         NaN           yes
# 2       5.0    male     NaN          2  ungraduate           NaN
# 3      65.0     NaN      no         3+         NaN            no
# 4     767.0  female     yes          2    graduate           NaN
# 5       8.0     NaN     NaN        NaN         NaN           yes
# 6      78.0  female     NaN          1  ungraduate           NaN
# 7       NaN    male     yes          0         NaN           yes
# 8      89.0    male      no        NaN         NaN            no
# 9      34.0     NaN      no          1         NaN            no
# 10     32.0     NaN     NaN          0  ungraduate            no
# 11     12.0    male      no         3+         NaN            no
#
#     applicantincome  coapplicant_income  loan_amount property
# 0          453453.0                   0        232.0    urban
# 1            5435.0                3434        232.0    rural
# 2            4545.0                   3         32.0    rural
# 3               NaN                3434          2.0    urban
# 4              23.0                3445        323.0    rural
# 5               NaN                 454          2.0    urban
# 6               NaN                 343         32.0    rural
# 7            4545.0               23223         32.0    urban
# 8           34094.0                 323          NaN    rural
# 9             232.0                 232        323.0    rural
# 10              4.0              232323        323.0      NaN
# 11        3287328.0                  12        323.0    rural

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   loan_id             11 non-null     float64
#  1   Gender              8 non-null      object
#  2   Married             8 non-null      object
#  3   Dependents          10 non-null     object
#  4   Education           5 non-null      object
#  5   self_employed       9 non-null      object
#  6   applicantincome     9 non-null      float64
#  7   coapplicant_income  12 non-null     int64
#  8   loan_amount         11 non-null     float64
#  9   property            11 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 1.1+ KB

# %%
dataset.fillna({"Dependents":dataset["Dependents"].mode()[0]},inplace=True)

# %%
dataset.isnull().sum()
# Out:
# loan_id               1
# Gender                4
# Married               4
# Dependents            0
# Education             7
# self_employed         3
# applicantincome       3
# coapplicant_income    0
# loan_amount           1
# property              1
# dtype: int64

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   loan_id             11 non-null     float64
#  1   Gender              8 non-null      object
#  2   Married             8 non-null      object
#  3   Dependents          12 non-null     object
#  4   Education           5 non-null      object
#  5   self_employed       9 non-null      object
#  6   applicantincome     9 non-null      float64
#  7   coapplicant_income  12 non-null     int64
#  8   loan_amount         11 non-null     float64
#  9   property            11 non-null     object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 1.1+ KB

# %%
dataset["Dependents"].value_counts()
# Out:
# Dependents
# 0     5
# 1     3
# 2     2
# 3+    2
# Name: count, dtype: int64

# %%
dataset.replace({"Dependents":{"3+","3"}},inplace=True)

# %%
dataset["Dependents"].value_counts()
# Out:
# Dependents
# 0    5
# 1    3
# 2    2
# 3    2
# Name: count, dtype: int64

# %%
dataset
# Out:
#     loan_id  Gender Married Dependents   Education self_employed  \
# 0      12.0    male      no          0    graduate            no
# 1      34.0  female     yes          1         NaN           yes
# 2       5.0    male     NaN          2  ungraduate           NaN
# 3      65.0     NaN      no          3         NaN            no
# 4     767.0  female     yes          2    graduate           NaN
# 5       8.0     NaN     NaN          0         NaN           yes
# 6      78.0  female     NaN          1  ungraduate           NaN
# 7       NaN    male     yes          0         NaN           yes
# 8      89.0    male      no          0         NaN            no
# 9      34.0     NaN      no          1         NaN            no
# 10     32.0     NaN     NaN          0  ungraduate            no
# 11     12.0    male      no          3         NaN            no
#
#     applicantincome  coapplicant_income  loan_amount property
# 0          453453.0                   0        232.0    urban
# 1            5435.0                3434        232.0    rural
# 2            4545.0                   3         32.0    rural
# 3               NaN                3434          2.0    urban
# 4              23.0                3445        323.0    rural
# 5               NaN                 454          2.0    urban
# 6               NaN                 343         32.0    rural
# 7            4545.0               23223         32.0    urban
# 8           34094.0                 323          NaN    rural
# 9             232.0                 232        323.0    rural
# 10              4.0              232323        323.0      NaN
# 11        3287328.0                  12        323.0    rural
