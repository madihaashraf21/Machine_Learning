# %%
import pandas as pd

# %%
dataset=pd.read_csv("loan.csv")

# %%
# dataset.fillna(10) wrong way

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   loan_id             8 non-null      float64
#  1   Gender              6 non-null      object
#  2   Married             6 non-null      object
#  3   Dependents          6 non-null      float64
#  4   Education           4 non-null      object
#  5   self_employed       6 non-null      object
#  6   applicantincome     5 non-null      float64
#  7   coapplicant_income  9 non-null      int64
#  8   loan_amount         9 non-null      int64
#  9   property            9 non-null      object
# dtypes: float64(3), int64(2), object(5)
# memory usage: 852.0+ bytes

# %%
dataset.bfill()
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0  ungraduate           yes
# 2      5.0    male      no         2.0  ungraduate            no
# 3     65.0  female      no         2.0    graduate            no
# 4    767.0  female     yes         2.0    graduate           yes
# 5      8.0  female     yes         1.0  ungraduate           yes
# 6     78.0  female     yes         1.0  ungraduate           yes
# 7     89.0    male     yes         0.0         NaN           yes
# 8     89.0     NaN      no         NaN         NaN            no
#
#    applicantincome  coapplicant_income  loan_amount property
# 0         453453.0                   0          232    urban
# 1           5435.0                3434          232    rural
# 2           4545.0                   3           32    rural
# 3           4545.0                3434            2    urban
# 4           4545.0                3445          323    rural
# 5           4545.0                 454            2    urban
# 6           4545.0                 343           32    rural
# 7           4545.0               23223           32    urban
# 8              4.0                 323          323    rural

# %%
dataset.fillna(method="ffill",axis=1)
# Out:
# C:\Users\Mrd74\AppData\Local\Temp\ipykernel_17496\629923051.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   dataset.fillna(method="ffill",axis=1)
#   loan_id  Gender Married Dependents   Education self_employed  \
# 0    12.0    male      no        0.0    graduate            no
# 1    34.0  female     yes        1.0         1.0           yes
# 2     5.0    male    male        2.0  ungraduate    ungraduate
# 3    65.0    65.0      no         no          no            no
# 4   767.0  female     yes        2.0    graduate      graduate
# 5     8.0     8.0     8.0        8.0         8.0           yes
# 6    78.0  female  female        1.0  ungraduate    ungraduate
# 7     NaN    male     yes        0.0         0.0           yes
# 8    89.0    89.0      no         no          no            no
#
#   applicantincome coapplicant_income loan_amount property
# 0        453453.0                  0         232    urban
# 1          5435.0               3434         232    rural
# 2          4545.0                  3          32    rural
# 3              no               3434           2    urban
# 4        graduate               3445         323    rural
# 5             yes                454           2    urban
# 6      ungraduate                343          32    rural
# 7          4545.0              23223          32    urban
# 8             4.0                323         323    rural

# %%
dataset.head(10)
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0         NaN           yes
# 2      5.0    male     NaN         2.0  ungraduate           NaN
# 3     65.0     NaN      no         NaN         NaN            no
# 4    767.0  female     yes         2.0    graduate           NaN
# 5      8.0     NaN     NaN         NaN         NaN           yes
# 6     78.0  female     NaN         1.0  ungraduate           NaN
# 7      NaN    male     yes         0.0         NaN           yes
# 8     89.0     NaN      no         NaN         NaN            no
#
#    applicantincome  coapplicant_income  loan_amount property
# 0         453453.0                   0          232    urban
# 1           5435.0                3434          232    rural
# 2           4545.0                   3           32    rural
# 3              NaN                3434            2    urban
# 4              NaN                3445          323    rural
# 5              NaN                 454            2    urban
# 6              NaN                 343           32    rural
# 7           4545.0               23223           32    urban
# 8              4.0                 323          323    rural

# %%
dataset.isnull().sum()
# Out:
# loan_id               1
# Gender                3
# Married               3
# Dependents            3
# Education             5
# self_employed         3
# applicantincome       4
# coapplicant_income    0
# loan_amount           0
# property              0
# dtype: int64

# %%
dataset["Gender"].mode()[0]
# Out:
# 'female'

# %%
dataset["Gender"].fillna(dataset["Gender"].mode()[0],inplace=True)
# Out:
# C:\Users\Mrd74\AppData\Local\Temp\ipykernel_17496\3181356174.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset["Gender"].fillna(dataset["Gender"].mode()[0],inplace=True)

# %%
dataset.isnull().sum()
# Out:
# loan_id               1
# Gender                0
# Married               3
# Dependents            3
# Education             5
# self_employed         3
# applicantincome       4
# coapplicant_income    0
# loan_amount           0
# property              0
# dtype: int64

# %%
dataset.select_dtypes(object).columns
# Out:
# Index(['Gender', 'Married', 'Education', 'self_employed', 'property'], dtype='object')

# %%
for i in dataset.select_dtypes(object).columns:
    dataset[i].fillna(dataset[i].mode()[0],inplace =True)
# Out:
# C:\Users\Mrd74\AppData\Local\Temp\ipykernel_17496\2976160624.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   dataset[i].fillna(dataset[i].mode()[0],inplace =True)

# %%
dataset.head(10)
# Out:
#    loan_id  Gender Married  Dependents   Education self_employed  \
# 0     12.0    male      no         0.0    graduate            no
# 1     34.0  female     yes         1.0    graduate           yes
# 2      5.0    male      no         2.0  ungraduate            no
# 3     65.0  female      no         NaN    graduate            no
# 4    767.0  female     yes         2.0    graduate            no
# 5      8.0  female      no         NaN    graduate           yes
# 6     78.0  female      no         1.0  ungraduate            no
# 7      NaN    male     yes         0.0    graduate           yes
# 8     89.0  female      no         NaN    graduate            no
#
#    applicantincome  coapplicant_income  loan_amount property
# 0         453453.0                   0          232    urban
# 1           5435.0                3434          232    rural
# 2           4545.0                   3           32    rural
# 3              NaN                3434            2    urban
# 4              NaN                3445          323    rural
# 5              NaN                 454            2    urban
# 6              NaN                 343           32    rural
# 7           4545.0               23223           32    urban
# 8              4.0                 323          323    rural

# %%
dataset.isnull().sum()
# Out:
# loan_id               1
# Gender                0
# Married               0
# Dependents            3
# Education             0
# self_employed         0
# applicantincome       4
# coapplicant_income    0
# loan_amount           0
# property              0
# dtype: int64
